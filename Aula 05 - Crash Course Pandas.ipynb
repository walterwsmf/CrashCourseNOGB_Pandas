# %% [markdown]
# # Aula 05 Crash Course Pandas
#
# ## Objetivo:
#
# Objetivo desta aula é apresentar apresentar como dataframes pandas podem ser usados em problemas de regressão com statsmodels e outros pacotes.
#
#
# ## Roteiro da aula:
#
# - StatsModel OLS
#
# - StatsModel Multi-linear OLS
#
# - Pandas + Scikit Regressão linear
#
# - Metodologia de KFold
#
# - Rolling Windown OLS
#
# - Regressão Por percentil
#
# - Analise de Tendencias por PCA
#
#
# ## Referências
#
# - [Extensões do Jupyter: artigo no Medium](https://medium.com/@seymatas/5-jupyter-notebook-extensions-for-a-fully-organized-data-science-project-d764195f91be)
#
# - [Instalando extensões do jupyter e possíveis erros - slackoverflow](https://stackoverflow.com/questions/37718907/variable-explorer-in-jupyter-notebook)
#
# - [Pandas](https://pandas.pydata.org/)
#
# - [Introdução em 10 minutos do Pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html)
#
# - [Documentação Pandas: Guia do usuário](https://pandas.pydata.org/docs/user_guide/index.html#user-guide)
#
# - [GitHub Cheat Sheet Markdown](https://github.com/adam-p/markdown-here/wiki/Markdown-Here-Cheatsheet)
#
# - [Numpy](https://numpy.org/)
#
# - [Kaggle Titanic Data](https://www.kaggle.com/c/titanic/data)
#
# - [Split-Apply-Combine Pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html)
#
# - [Colunas Categóricas](https://pandas.pydata.org/pandas-docs/stable/user_guide/categorical.html)
#
# - [Selecionando colunas pelo tipo de variável](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.select_dtypes.html)
#
# - [Merge, Join, Concatanate](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)
#
# - [Pacote Seaborn](https://seaborn.pydata.org/)
#
# - [Seaborn Tutoriais](https://seaborn.pydata.org/tutorial.html)
#
# - [Overview das figuras de seaborn](https://seaborn.pydata.org/tutorial/function_overview.html)
#
# - [Regra 68–95–99.7](https://en.wikipedia.org/wiki/68%E2%80%9395%E2%80%9399.7_rule)
#
# - [Dados do **Open Power System** da Alemanha](https://data.open-power-system-data.org/time_series/)
#
# - [Análise temporal dos dados de Consumo de Energia entre 2006 e 2017 da Alemanha](https://www.dataquest.io/blog/tutorial-time-series-analysis-with-pandas/)
#
# - [Análise de dados Climáticos de Londres](https://medium.com/@emafuma/simple-time-series-eda-using-pandas-and-seaborn-b3e2ef9636e6)
#
# - [Mapa de cor (heatmap) para série temporal com Pandas](https://jonisalonen.com/2019/plotting-a-time-series-heat-map-with-pandas/)
#
# - [Visualização de Séries Temporais com Seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html)
#
# - [Pacote fbprophet, ou Prophet](https://facebook.github.io/prophet/)
#
# - [Caso plt.figure para figsize não funcione no seaborn, use aspect](https://stackoverflow.com/questions/31594549/how-do-i-change-the-figure-size-for-a-seaborn-plot/51602446#51602446)
#
# - [Timezone e Objetos Datetime](https://howchoo.com/g/ywi5m2vkodk/working-with-datetime-objects-and-timezones-in-python)
#
# - [Regressão Linear com Pandas e Scikit](https://www.kaggle.com/wdiego/linear-regression-with-pandas-scikit-learn)
#
# - [Regressão Multi-linear com Pandas e StatsModel](https://datatofish.com/multiple-linear-regression-python/)
#
# - [Predizendo preços de imóveis - Medium post](https://www.learndatasci.com/tutorials/predicting-housing-prices-linear-regression-using-python-pandas-statsmodels/)
#
# - [Kaggle: Predizendo preços de imóveis](https://www.kaggle.com/c/house-prices-advanced-regression-techniques)
#
# - [Dataset de Preços de Imóveis](https://github.com/LearnDataSci/articles/tree/master/Housing%20Price%20Index%20Regression)
#
# - [Gráfico de Resíduo Parcial](https://www.itl.nist.gov/div898/software/dataplot/refman1/auxillar/partresi.htm)
#
# - [Como montar Validação de modelo cruzado por KFold - Medium Post em PT-BR](https://medium.com/data-hackers/como-criar-k-fold-cross-validation-na-m%C3%A3o-em-python-c0bb06074b6b)
#
# - [Figura KFold](https://www.researchgate.net/figure/The-technique-of-KFold-cross-validation-illustrated-here-for-the-case-K-4-involves_fig10_278826818)
#
# - [Fama-Frech Factor em Finanças](http://www.reproduciblefinance.com/code/fama-french-three-factor-model/)
#
# - [Explicação do 3 Fama French Factor](https://www.investopedia.com/terms/f/famaandfrenchthreefactormodel.asp#:~:text=The%20Fama%20and%20French%20model,risk%20free%20rate%20of%20return.)
#
# - [Variáveis Exog e Endog](https://www.statsmodels.org/stable/endog_exog.html)
#
# - [Intervalo de confiança por matrizes de Hessian](http://sherrytowers.com/2014/09/23/estimating-parameter-confidence-intervals-when-using-the-parameter-sweep-optimization-method/)
#
# ## Contato:
#
# - E-mails:
#
#     - walter@on.br
#
#     - walter@neuralmed.ai
#
#     - walterwsmf@outlook.com
#
# - Redes Sociais:
#
#     - [LinkedIn](https://www.linkedin.com/in/walterwsmf/)
#
#     - [Twitter](https://twitter.com/walterwsmf)
#
# ### Agradecimento:
#
# Agradecimentos a cientista [Jenifer](https://github.com/jenfly) que disponibilizou pre-processamento:
#
# https://github.com/jenfly/opsd/blob/master/time-series-preprocessing.ipynb

# %%
# %%time 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

sns.set(rc={'figure.figsize':(14, 6)})
# Out:
# CPU times: user 1.15 s, sys: 506 ms, total: 1.66 s
# Wall time: 4.33 s

# %%
# %%time
import statsmodels.api as sm
from statsmodels.formula.api import ols #ordinary least square 
from statsmodels.sandbox.regression.predstd import wls_prediction_std
# Out:
# CPU times: user 367 ms, sys: 231 ms, total: 598 ms
# Wall time: 2.02 s

# %%
# %%time
root = 'https://raw.githubusercontent.com/LearnDataSci/article-resources/master/Housing%20Price%20Index%20Regression'

housing_price_index = pd.read_csv(root + '/monthly-hpi.csv') #variacao do preco das casas diariamente

unemployment = pd.read_csv(root + '/unemployment-macro.csv') # taxa de desemprego

federal_funds_rate = pd.read_csv(root + '/fed_funds.csv') # taxa entre bancos com interesse imobiliario 

shiller = pd.read_csv(root + '/shiller.csv') # inflacao 

gross_domestic_product = pd.read_csv(root + '/gdp.csv') #produto interno bruto
# Out:
# CPU times: user 121 ms, sys: 21.5 ms, total: 142 ms
# Wall time: 1.92 s

# %% [markdown]
# ### Dicionário de variáveis:
#
# https://github.com/LearnDataSci/articles/tree/master/Housing%20Price%20Index%20Regression

# %%
housing_price_index.head()
# Out:
#          date  housing_price_index
# 0  2010-11-01               186.07
# 1  2010-12-01               183.27
# 2  2011-01-01               181.35
# 3  2011-02-01               179.66
# 4  2011-03-01               178.84

# %%
unemployment.head()
# Out:
#          date  total_unemployed  more_than_15_weeks  \
# 0  2010-11-01              16.9                8696
# 1  2010-12-01              16.6                8549
# 2  2011-01-01              16.2                8393
# 3  2011-02-01              16.0                8175
# 4  2011-03-01              15.9                8166
#
#    not_in_labor_searched_for_work  multi_jobs  leavers  losers
# 0                            2531        6708      5.7    63.0
# 1                            2609        6899      6.4    61.2
# 2                            2800        6816      6.5    60.1
# 3                            2730        6741      6.4    60.2
# 4                            2434        6735      6.4    60.3

# %%
federal_funds_rate.head()
# Out:
#          date  federal_funds_rate
# 0  2010-11-01                0.19
# 1  2010-12-01                0.18
# 2  2011-01-01                0.17
# 3  2011-02-01                0.16
# 4  2011-03-01                0.14

# %%
shiller.head()
# Out:
#          date    sp500  consumer_price_index  long_interest_rate
# 0  2010-11-01  1198.89                218.80                2.76
# 1  2010-12-01  1241.53                219.18                3.29
# 2  2011-01-01  1282.62                220.22                3.39
# 3  2011-02-01  1321.12                221.31                3.58
# 4  2011-03-01  1304.49                223.47                3.41

# %%
gross_domestic_product.head()
# Out:
#          date  total_expenditures  labor_force_pr  producer_price_index  \
# 0  2011-01-01              5766.7            64.2                 192.7
# 1  2011-04-01              5870.8            64.2                 203.1
# 2  2011-07-01              5802.6            64.0                 204.6
# 3  2011-10-01              5812.9            64.1                 201.1
# 4  2012-01-01              5765.7            63.7                 200.7
#
#    gross_domestic_product
# 0                 14881.3
# 1                 14989.6
# 2                 15021.1
# 3                 15190.3
# 4                 15291.0

# %% [markdown]
# ### Podemos perceber que todos datasets possuem a coluna de data em comum

# %%
# usando merge sequencial
df = (shiller.merge(housing_price_index, on='date')
                      .merge(unemployment, on='date')
                       .merge(federal_funds_rate, on='date')
                        .merge(gross_domestic_product, on='date'))

# %%
df.head()
# Out:
#          date    sp500  consumer_price_index  long_interest_rate  \
# 0  2011-01-01  1282.62                220.22                3.39
# 1  2011-04-01  1331.51                224.91                3.46
# 2  2011-07-01  1325.19                225.92                3.00
# 3  2011-10-01  1207.22                226.42                2.15
# 4  2012-01-01  1300.58                226.66                1.97
#
#    housing_price_index  total_unemployed  more_than_15_weeks  \
# 0               181.35              16.2                8393
# 1               180.80              16.1                8016
# 2               184.25              15.9                8177
# 3               181.51              15.8                7802
# 4               179.13              15.2                7433
#
#    not_in_labor_searched_for_work  multi_jobs  leavers  losers  \
# 0                            2800        6816      6.5    60.1
# 1                            2466        6823      6.8    59.4
# ...

# %%
del housing_price_index, unemployment, federal_funds_rate, gross_domestic_product

# %% [markdown]
# ## Regressão por mínimos quadrados ordinários:
#
# ### Suposições:
#
# - linearidade
#
# - inexistência de multicolonariedade, i.e., as variáveis independentes não deveriam possuir correlação
#
# - média condicional zero: os resíduos entre a tendência e o conjunto de dados deve estar próxima de zero.
#
# - Homocedasticidade: inexistência de tendência nos resíduos entre modelo e o conj. de dados.
#
# - Inexistência de autocorrelação: i.e., a variável não deve possuir correlação entre seus pares com dados antes ou após em relação a variável dependente.

# %%
df = df.set_index("date")

# %%
df
# Out:
#               sp500  consumer_price_index  long_interest_rate  \
# date
# 2011-01-01  1282.62                220.22                3.39
# 2011-04-01  1331.51                224.91                3.46
# 2011-07-01  1325.19                225.92                3.00
# 2011-10-01  1207.22                226.42                2.15
# 2012-01-01  1300.58                226.66                1.97
# 2012-04-01  1386.43                230.09                2.05
# 2012-07-01  1359.78                229.10                1.53
# 2012-10-01  1437.82                231.32                1.75
# 2013-01-01  1480.40                230.28                1.91
# 2013-04-01  1570.70                232.53                1.76
# 2013-07-01  1668.68                233.60                2.58
# 2013-10-01  1720.03                233.55                2.62
# 2014-01-01  1822.36                233.92                2.86
# 2014-04-01  1864.26                237.07                2.71
# ...

# %%
df['housing_price_index'].plot(linewidth=3)
plt.ylabel('Housing Price Index')
# Out:
# /Users/walter/opt/anaconda3/envs/CrashCourse/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Text(0, 0.5, 'Housing Price Index')

# %%
sns.regplot(x='total_unemployed',y='housing_price_index',data=df)
# Out:
# <AxesSubplot:xlabel='total_unemployed', ylabel='housing_price_index'>

# %%
# fit com statsmodel
housing_model = ols("housing_price_index ~ total_unemployed", data=df).fit() #formula com nomes das colunas

# %%
housing_model

# %%
help(ols)
# Out:
# Help on method from_formula in module statsmodels.base.model:
#
# from_formula(formula, data, subset=None, drop_cols=None, *args, **kwargs) method of builtins.type instance
#     Create a Model from a formula and dataframe.
#
#     Parameters
#     ----------
#     formula : str or generic Formula object
#         The formula specifying the model.
#     data : array_like
#         The data for the model. See Notes.
#     subset : array_like
#         An array-like object of booleans, integers, or index values that
#         indicate the subset of df to use in the model. Assumes df is a
#         `pandas.DataFrame`.
#     drop_cols : array_like
#         Columns to drop from the design matrix.  Cannot be used to
#         drop terms involving categoricals.
#     *args
#         Additional positional argument that are passed to the model.
#     **kwargs
#         These are passed to the model with one exception. The
#         ``eval_env`` keyword is passed to patsy. It can be either a
# ...

# %% [markdown]
# ### Regressão Geral linear
#
# $y \sim \sum a_{i} \times x_{i} + \epsilon$
#
# Modelo regressão:
#
# $HousingPriceIndex \sim coef \times TotalUnemployed + intercept$

# %%
# sumario do modelo
housing_model.summary() #"housing_price_index ~ total_unemployed"
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     housing_price_index   R-squared:                       0.952
# Model:                             OLS   Adj. R-squared:                  0.949
# Method:                  Least Squares   F-statistic:                     413.2
# Date:                 Fri, 02 Oct 2020   Prob (F-statistic):           2.71e-15
# Time:                         10:32:50   Log-Likelihood:                -65.450
# No. Observations:                   23   AIC:                             134.9
# Df Residuals:                       21   BIC:                             137.2
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(housing_model, "total_unemployed", fig=fig)

# %% [markdown]
# ### Vamos verificar intervalo de confiança:

# %%
x = df[['total_unemployed']]
y = df[['housing_price_index']]

# %%
_, confidence_interval_lower, confidence_interval_upper = wls_prediction_std(housing_model)

# %%
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(x, y, 'o', label="data")
ax.plot(x, housing_model.fittedvalues, 'g--.', label="OLS")
# pintervalo de confianca
ax.plot(x, confidence_interval_upper, 'r--')
ax.plot(x, confidence_interval_lower, 'r--')
plt.xlabel('total_unemployed')
plt.ylabel('housing_price_index')
ax.legend(loc='best');

# %% [markdown]
# ## Regressão  Multi-linear

# %%
housing_model = ols("""housing_price_index ~ total_unemployed 
                                            + long_interest_rate 
                                            + federal_funds_rate
                                            + consumer_price_index 
                                            + gross_domestic_product""", data=df).fit()
housing_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     housing_price_index   R-squared:                       0.980
# Model:                             OLS   Adj. R-squared:                  0.974
# Method:                  Least Squares   F-statistic:                     168.5
# Date:                 Fri, 02 Oct 2020   Prob (F-statistic):           7.32e-14
# Time:                         10:39:20   Log-Likelihood:                -55.164
# No. Observations:                   23   AIC:                             122.3
# Df Residuals:                       17   BIC:                             129.1
# Df Model:                            5
# Covariance Type:             nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
fig = plt.figure(figsize=(20,12))
fig = sm.graphics.plot_partregress_grid(housing_model, fig=fig)

# %%
_, confidence_interval_lower, confidence_interval_upper = wls_prediction_std(housing_model)

# %%
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(x, y, 'o', label="data")
ax.plot(x, housing_model.fittedvalues, 'g--.', label="OLS STATSMODEL")
# pintervalo de confianca
ax.plot(x, confidence_interval_upper, 'r--')
ax.plot(x, confidence_interval_lower, 'r--')
plt.xlabel('total_unemployed')
plt.ylabel('housing_price_index')
ax.legend(loc='best');

# %% [markdown]
# ### Como fazer OLS com Scikit ?

# %%
from sklearn import preprocessing
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression

# %%
df.isnull().sum()
# Out:
# sp500                             0
# consumer_price_index              0
# long_interest_rate                0
# housing_price_index               0
# total_unemployed                  0
# more_than_15_weeks                0
# not_in_labor_searched_for_work    0
# multi_jobs                        0
# leavers                           0
# losers                            0
# federal_funds_rate                0
# total_expenditures                0
# labor_force_pr                    0
# producer_price_index              0
# gross_domestic_product            0
# dtype: int64

# %%
df.hist(figsize=(14,14))
# Out:
# array([[<AxesSubplot:title={'center':'sp500'}>,
#         <AxesSubplot:title={'center':'consumer_price_index'}>,
#         <AxesSubplot:title={'center':'long_interest_rate'}>,
#         <AxesSubplot:title={'center':'housing_price_index'}>],
#        [<AxesSubplot:title={'center':'total_unemployed'}>,
#         <AxesSubplot:title={'center':'more_than_15_weeks'}>,
#         <AxesSubplot:title={'center':'not_in_labor_searched_for_work'}>,
#         <AxesSubplot:title={'center':'multi_jobs'}>],
#        [<AxesSubplot:title={'center':'leavers'}>,
#         <AxesSubplot:title={'center':'losers'}>,
#         <AxesSubplot:title={'center':'federal_funds_rate'}>,
#         <AxesSubplot:title={'center':'total_expenditures'}>],
#        [<AxesSubplot:title={'center':'labor_force_pr'}>,
#         <AxesSubplot:title={'center':'producer_price_index'}>,
#         <AxesSubplot:title={'center':'gross_domestic_product'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
X = pd.DataFrame(df['total_unemployed'])
y = pd.DataFrame(df['housing_price_index'])

# %%
model = LinearRegression()
scores = []
kfold = KFold(n_splits=3, shuffle=True, random_state=42) #np.random.seed

# %%
help(LinearRegression)
# Out:
# Help on class LinearRegression in module sklearn.linear_model._base:
#
# class LinearRegression(sklearn.base.MultiOutputMixin, sklearn.base.RegressorMixin, LinearModel)
#  |  LinearRegression(*, fit_intercept=True, normalize=False, copy_X=True, n_jobs=None)
#  |
#  |  Ordinary least squares Linear Regression.
#  |
#  |  LinearRegression fits a linear model with coefficients w = (w1, ..., wp)
#  |  to minimize the residual sum of squares between the observed targets in
#  |  the dataset, and the targets predicted by the linear approximation.
#  |
#  |  Parameters
#  |  ----------
#  |  fit_intercept : bool, default=True
#  |      Whether to calculate the intercept for this model. If set
#  |      to False, no intercept will be used in calculations
#  |      (i.e. data is expected to be centered).
#  |
#  |  normalize : bool, default=False
#  |      This parameter is ignored when ``fit_intercept`` is set to False.
# ...

# %%
help(KFold)
# Out:
# Help on class KFold in module sklearn.model_selection._split:
#
# class KFold(_BaseKFold)
#  |  KFold(n_splits=5, *, shuffle=False, random_state=None)
#  |
#  |  K-Folds cross-validator
#  |
#  |  Provides train/test indices to split data in train/test sets. Split
#  |  dataset into k consecutive folds (without shuffling by default).
#  |
#  |  Each fold is then used once as a validation while the k - 1 remaining
#  |  folds form the training set.
#  |
#  |  Read more in the :ref:`User Guide <cross_validation>`.
#  |
#  |  Parameters
#  |  ----------
#  |  n_splits : int, default=5
#  |      Number of folds. Must be at least 2.
#  |
#  |      .. versionchanged:: 0.22
#  |          ``n_splits`` default value changed from 3 to 5.
#  |
#  |  shuffle : bool, default=False
#  |      Whether to shuffle the data before splitting into batches.
#  |      Note that the samples within each split will not be shuffled.
#  |
#  |  random_state : int or RandomState instance, default=None
# ...

# %%
# %%time
scores = []
for i, (train, test) in enumerate(kfold.split(X, y)):
    model.fit(X.iloc[train,:], y.iloc[train,:])
    
    score = model.score(X.iloc[test,:], y.iloc[test,:])
    
    scores.append(score)

print(scores)
# Out:
# [0.9650250134584509, 0.9321037645437151, 0.8910379254908114]
# CPU times: user 52 ms, sys: 4.67 ms, total: 56.7 ms
# Wall time: 86.9 ms

# %%
help(model.score)
# Out:
# Help on method score in module sklearn.base:
#
# score(X, y, sample_weight=None) method of sklearn.linear_model._base.LinearRegression instance
#     Return the coefficient of determination R^2 of the prediction.
#
#     The coefficient R^2 is defined as (1 - u/v), where u is the residual
#     sum of squares ((y_true - y_pred) ** 2).sum() and v is the total
#     sum of squares ((y_true - y_true.mean()) ** 2).sum().
#     The best possible score is 1.0 and it can be negative (because the
#     model can be arbitrarily worse). A constant model that always
#     predicts the expected value of y, disregarding the input features,
#     would get a R^2 score of 0.0.
#
#     Parameters
#     ----------
#     X : array-like of shape (n_samples, n_features)
#         Test samples. For some estimators this may be a
#         precomputed kernel matrix or a list of generic objects instead,
#         shape = (n_samples, n_samples_fitted),
#         where n_samples_fitted is the number of
# ...

# %%
pred = model.predict(X)

# %%
pred
# Out:
# array([[178.55289411],
#        [179.33957657],
#        [180.91294148],
#        [181.69962394],
#        [186.4197187 ],
#        [191.13981345],
#        [189.56644853],
#        [192.71317837],
#        [191.92649591],
#        [195.85990821],
#        [197.43327312],
#        [199.00663804],
#        [206.08678017],
#        [209.23351001],
#        [210.02019247],
#        [215.52696968],
#        [217.1003346 ],
#        [221.0337469 ],
#        [224.96715919],
#        [228.90057149],
#        [228.11388903],
#        [229.68725395],
#        [229.68725395]])

# %%
housing_model = ols("housing_price_index ~ total_unemployed", data=df).fit()
_, confidence_interval_lower, confidence_interval_upper = wls_prediction_std(housing_model)

# %%
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(x, y, 'o', label="data",color='black')
ax.plot(x, housing_model.fittedvalues, 'g--.', label="OLS STATSMODEL",lw=3)
ax.plot(x, pred, 'b-.', label="OLS Scikit",lw=3)

# pintervalo de confianca
ax.plot(x, confidence_interval_upper, 'r--')
ax.plot(x, confidence_interval_lower, 'r--')
plt.xlabel('total_unemployed')
plt.ylabel('housing_price_index')
ax.legend(loc='best');

# %% [markdown]
# ## Rolling Least Square
#
# Instalacao do pacote  pandas_datareader permite baixar dados de industria aresentados desde 1926 coletados pela Universidade de Dartmouth
#
# - **"The two data sets downloaded are the 3 Fama-French factors and the 10 industry portfolios."**
#
#
# ###  3-FAMA French Factor
#
# " The Fama and French model has three factors: **size of firms**, **book-to-market values** and **excess return on the market**. In other words, the three factors used are **SMB (small minus big)**, **HML (high minus low)** and the **portfolio's return less the risk free rate of return**. SMB accounts for publicly traded companies with small market caps that generate higher returns, while HML accounts for value stocks with high book-to-market ratios that generate higher returns in comparison to the market. " -- [Investopedia](https://www.investopedia.com/terms/f/famaandfrenchthreefactormodel.asp#:~:text=The%20Fama%20and%20French%20model,risk%20free%20rate%20of%20return.)

# %%
#!pip install pandas_datareader

# %%
import pandas_datareader as pdr
from statsmodels.regression.rolling import RollingOLS

# %%
data = pdr.get_data_famafrench('F-F_Research_Data_Factors', start='1-1-1926')

# %%
data.keys()
# Out:
# dict_keys([0, 1, 'DESCR'])

# %%
import pprint

# %%
pprint.pprint(data['DESCR'])
# Out:
# ('F-F Research Data Factors\n'
#  '-------------------------\n'
#  '\n'
#  'This file was created by CMPT_ME_BEME_RETS using the 202008 CRSP database. '
#  'The 1-month TBill return is from Ibbotson and Associates, Inc. Copyright '
#  '2020 Kenneth R. French\n'
#  '\n'
#  '  0 : (1130 rows x 4 cols)\n'
#  '  1 : Annual Factors: January-December (93 rows x 4 cols)')

# %%
factors = pdr.get_data_famafrench('F-F_Research_Data_Factors', start='1-1-1926')[0]
print(factors.head())
# Out:
#          Mkt-RF   SMB   HML    RF
# Date
# 1926-07    2.96 -2.30 -2.87  0.22
# 1926-08    2.64 -1.40  4.19  0.25
# 1926-09    0.36 -1.32  0.01  0.23
# 1926-10   -3.24  0.04  0.51  0.32
# 1926-11    2.53 -0.20 -0.35  0.31

# %%
industries = pdr.get_data_famafrench('10_Industry_Portfolios', start='1-1-1926')[0]
print(industries.head())
# Out:
#          NoDur  Durbl  Manuf  Enrgy  HiTec  Telcm  Shops  Hlth   Utils  Other
# Date
# 1926-07   1.45  15.55   4.69  -1.18   2.90   0.83   0.11   1.77   7.04   2.16
# 1926-08   3.97   3.68   2.81   3.47   2.66   2.17  -0.71   4.25  -1.69   4.38
# 1926-09   1.14   4.80   1.15  -3.39  -0.38   2.41   0.21   0.69   2.04   0.29
# 1926-10  -1.24  -8.23  -3.63  -0.78  -4.58  -0.11  -2.29  -0.57  -2.63  -2.85
# 1926-11   5.20  -0.19   4.10   0.01   4.71   1.63   6.43   5.42   3.71   2.11

# %% [markdown]
# ### Variaveis Endog e Exog
#
# endog - variavel endog são as variaveis dependentes ou regressores
#
# exog - variável exog são variáveis independentes no modelo

# %%
industries['HiTec'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
factors["RF"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
fig, ax = plt.subplots(2,1,figsize=(14,7))
ax[0].plot(industries['HiTec'], factors['Mkt-RF'], 'o', label='HiTec',color='black')
ax[1].plot(factors["RF"], factors['Mkt-RF'], '+', label='RF',color='b')
ax[0].legend(loc='best');
ax[1].legend(loc='best');
ax[1].set_ylabel('Mkt-RF')
ax[0].set_xlabel('HiTec')
ax[1].set_xlabel('RF')
# Out:
# Text(0.5, 0, 'RF')

# %%
endog = industries.HiTec - factors.RF.values
exog = sm.add_constant(factors['Mkt-RF'])

# %%
industries.index
# Out:
# PeriodIndex(['1926-07', '1926-08', '1926-09', '1926-10', '1926-11', '1926-12',
#              '1927-01', '1927-02', '1927-03', '1927-04',
#              ...
#              '2019-11', '2019-12', '2020-01', '2020-02', '2020-03', '2020-04',
#              '2020-05', '2020-06', '2020-07', '2020-08'],
#             dtype='period[M]', name='Date', length=1130, freq='M')

# %% [markdown]
# ### Como temos muitos dados, vamos fazer rolling window de 60 meses

# %%
12*5
# Out:
# 60

# %%
# %%time
rols = RollingOLS(endog, exog, window=60)
rres = rols.fit()

params = rres.params
print(params.head())
print(params.tail())
# Out:
#          const  Mkt-RF
# Date
# 1926-07    NaN     NaN
# 1926-08    NaN     NaN
# 1926-09    NaN     NaN
# 1926-10    NaN     NaN
# 1926-11    NaN     NaN
#             const    Mkt-RF
# Date
# 2020-04  0.646019  1.034730
# 2020-05  0.671702  1.042427
# 2020-06  0.761960  1.040963
# 2020-07  0.762971  1.041435
# 2020-08  0.790354  1.049714
# CPU times: user 310 ms, sys: 9.77 ms, total: 320 ms
# Wall time: 463 ms

# %%
fig = rres.plot_recursive_coefficient(variables=['Mkt-RF'], figsize=(14,6))

# %%
help(rres.plot_recursive_coefficient)
# Out:
# Help on method plot_recursive_coefficient in module statsmodels.regression.rolling:
#
# plot_recursive_coefficient(variables=None, alpha=0.05, legend_loc='upper left', fig=None, figsize=None) method of statsmodels.regression.rolling.RollingRegressionResults instance
#     Plot the recursively estimated coefficients on a given variable
#
#     Parameters
#     ----------
#     variables : {int, str, Iterable[int], Iterable[str], None}, optional
#         Integer index or string name of the variables whose coefficients
#         to plot. Can also be an iterable of integers or strings. Default
#         plots all coefficients.
#     alpha : float, optional
#         The confidence intervals for the coefficient are (1 - alpha)%. Set
#         to None to exclude confidence intervals.
#     legend_loc : str, optional
#         The location of the legend in the plot. Default is upper left.
#     fig : Figure, optional
# ...

# %%
exog_vars = ['Mkt-RF', 'SMB', 'HML']
exog = sm.add_constant(factors[exog_vars])
rols = RollingOLS(endog, exog, window=60)
rres = rols.fit()

# %%
fig = rres.plot_recursive_coefficient(variables=exog_vars, figsize=(14,18))

# %% [markdown]
# # Combinando industria e factors

# %%
joined = pd.concat([factors, industries], axis=1)
joined['Mkt_RF'] = joined['Mkt-RF']

# %%
mod = RollingOLS.from_formula('HiTec ~ Mkt_RF + SMB + HML', data=joined, window=60)
rres = mod.fit()
print(rres.params.tail())
# Out:
#          Intercept    Mkt_RF       SMB       HML
# Date
# 2020-04   0.384183  1.126713 -0.131377 -0.356458
# 2020-05   0.388679  1.127575 -0.129201 -0.358668
# 2020-06   0.472303  1.117830 -0.083061 -0.368799
# 2020-07   0.478863  1.120159 -0.097486 -0.375933
# 2020-08   0.429972  1.135832 -0.108261 -0.389238

# %% [markdown]
# ## Regressão por Quartis (quantiles)

# %%
import statsmodels.formula.api as smf

# %%
data = sm.datasets.engel.load_pandas().data # dados de gasto com comida e salario 
data.head()
# Out:
#        income     foodexp
# 0  420.157651  255.839425
# 1  541.411707  310.958667
# 2  901.157457  485.680014
# 3  639.080229  402.997356
# 4  750.875606  495.560775

# %% [markdown]
# 1. Algoritmo do Desvio de Minimos Quadrados

# %%
mod = smf.quantreg('foodexp ~ income', data)

res = mod.fit(q=.5)

#print(res.summary())
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                          QuantReg Regression Results
# ...
# Dep. Variable:                foodexp   Pseudo R-squared:               0.6206
# Model:                       QuantReg   Bandwidth:                       64.51
# Method:                 Least Squares   Sparsity:                        209.3
# Date:                Fri, 02 Oct 2020   No. Observations:                  235
# Time:                        11:01:26   Df Residuals:                      233
#                                         Df Model:                            1
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     81.4823     14.634      5.568      0.000      52.649     110.315
# income         0.5602      0.013     42.516      0.000       0.534       0.586
# ...
#
# The condition number is large, 2.38e+03. This might indicate that there are
# ...

# %%
help(smf.quantreg)
# Out:
# Help on method from_formula in module statsmodels.base.model:
#
# from_formula(formula, data, subset=None, drop_cols=None, *args, **kwargs) method of builtins.type instance
#     Create a Model from a formula and dataframe.
#
#     Parameters
#     ----------
#     formula : str or generic Formula object
#         The formula specifying the model.
#     data : array_like
#         The data for the model. See Notes.
#     subset : array_like
#         An array-like object of booleans, integers, or index values that
#         indicate the subset of df to use in the model. Assumes df is a
#         `pandas.DataFrame`.
#     drop_cols : array_like
#         Columns to drop from the design matrix.  Cannot be used to
#         drop terms involving categoricals.
#     *args
#         Additional positional argument that are passed to the model.
#     **kwargs
#         These are passed to the model with one exception. The
#         ``eval_env`` keyword is passed to patsy. It can be either a
# ...

# %%
help(mod.fit) #hyperparametro q
# Out:
# Help on method fit in module statsmodels.regression.quantile_regression:
#
# fit(q=0.5, vcov='robust', kernel='epa', bandwidth='hsheather', max_iter=1000, p_tol=1e-06, **kwargs) method of statsmodels.regression.quantile_regression.QuantReg instance
#     Solve by Iterative Weighted Least Squares
#
#     Parameters
#     ----------
#     q : float
#         Quantile must be strictly between 0 and 1
#     vcov : str, method used to calculate the variance-covariance matrix
#         of the parameters. Default is ``robust``:
#
#         - robust : heteroskedasticity robust standard errors (as suggested
#           in Greene 6th edition)
#         - iid : iid errors (as in Stata 12)
#
#     kernel : str, kernel to use in the kernel density estimation for the
#         asymptotic covariance matrix:
#
#         - epa: Epanechnikov
#         - cos: Cosine
#         - gau: Gaussian
#         - par: Parzene
#
#     bandwidth : str, Bandwidth selection method in kernel density
# ...

# %% [markdown]
# ### pre-processamento: deteção de percentils

# %%
quantiles = np.arange(.05, .96, .1)

def fit_model(q):
    res = mod.fit(q=q)
    return [q, res.params['Intercept'], res.params['income']] + \
            res.conf_int().loc['income'].tolist()

# %%
# %%time
models = [fit_model(x) for x in quantiles]
models = pd.DataFrame(models, columns=['q', 'a', 'b', 'lb', 'ub'])
# Out:
# CPU times: user 641 ms, sys: 17.5 ms, total: 658 ms
# Wall time: 707 ms

# %%
models #a angular, b linear , lb lower bound, ub upper bound
# Out:
#       q           a         b        lb        ub
# 0  0.05  124.880097  0.343361  0.268632  0.418090
# 1  0.15  111.693660  0.423708  0.382780  0.464636
# 2  0.25   95.483539  0.474103  0.439900  0.508306
# 3  0.35  105.841294  0.488901  0.457759  0.520043
# 4  0.45   81.083647  0.552428  0.525021  0.579835
# 5  0.55   89.661370  0.565601  0.540955  0.590247
# 6  0.65   74.033435  0.604576  0.582169  0.626982
# 7  0.75   62.396584  0.644014  0.622411  0.665617
# 8  0.85   52.272216  0.677603  0.657383  0.697823
# 9  0.95   64.103964  0.709069  0.687831  0.730306

# %%
ols = smf.ols('foodexp ~ income', data).fit()
ols_ci = ols.conf_int().loc['income'].tolist()

ols = dict(a = ols.params['Intercept'],
           b = ols.params['income'],
           lb = ols_ci[0],
           ub = ols_ci[1])

print(f"Resultados da regressao por perncetils:\n {models} \n")
print(f"Resultados da regressao por ols:\n {ols} \n")
# Out:
# Resultados da regressao por perncetils:
#        q           a         b        lb        ub
# 0  0.05  124.880097  0.343361  0.268632  0.418090
# 1  0.15  111.693660  0.423708  0.382780  0.464636
# 2  0.25   95.483539  0.474103  0.439900  0.508306
# 3  0.35  105.841294  0.488901  0.457759  0.520043
# 4  0.45   81.083647  0.552428  0.525021  0.579835
# 5  0.55   89.661370  0.565601  0.540955  0.590247
# 6  0.65   74.033435  0.604576  0.582169  0.626982
# 7  0.75   62.396584  0.644014  0.622411  0.665617
# 8  0.85   52.272216  0.677603  0.657383  0.697823
# 9  0.95   64.103964  0.709069  0.687831  0.730306
#
# Resultados da regressao por ols:
#  {'a': 147.4753885237058, 'b': 0.4851784236769232, 'lb': 0.45687381301842295, 'ub': 0.5134830343354234}

# %%
x = np.arange(data.income.min(), data.income.max(), 50)
get_y = lambda a, b: a + b * x

fig, ax = plt.subplots(figsize=(8, 6))

for i in range(models.shape[0]):
    y = get_y(models.a[i], models.b[i])
    ax.plot(x, y, linestyle='dotted', color='grey')

y = get_y(ols['a'], ols['b'])

ax.plot(x, y, color='red', label='OLS')
ax.scatter(data.income, data.foodexp, alpha=.2)
ax.set_xlim((240, 3000))
ax.set_ylim((240, 2000))
legend = ax.legend()
ax.set_xlabel('Income', fontsize=16)
ax.set_ylabel('Food expenditure', fontsize=16);

# %% [markdown]
# # Pergunta: como fazer esse conjunto de soluções para primeiro caso de OLS (escalável para demais) ?

# %% [markdown]
# ### A diferenca mais drástica esta quando avaliamos um dos parâmetros do modelo por percentil da distribuição da vafriavel dependente:

# %%
n = models.shape[0]
p1 = plt.plot(models.q, models.b, color='black', label='Quantile Reg.')
p2 = plt.plot(models.q, models.ub, linestyle='dotted', color='black')
p3 = plt.plot(models.q, models.lb, linestyle='dotted', color='black')
p4 = plt.plot(models.q, [ols['b']] * n, color='red', label='OLS')
p5 = plt.plot(models.q, [ols['lb']] * n, linestyle='dotted', color='red')
p6 = plt.plot(models.q, [ols['ub']] * n, linestyle='dotted', color='red')
plt.ylabel(r'$\beta_{income}$')
plt.xlabel('Quantiles of the conditional food expenditure distribution')
plt.legend()
plt.show()

# %% [markdown]
# ## Análise por Componentes Principais PCA
#
# - Taxa de fertilidade em 192 países tabelado pelo Banco Mundial
#
#
# OBJETIVO: como a taxa de fertilidade varia de país para país.
#
# Em si, queremos encontrar tendências que não são claras

# %%
from statsmodels.multivariate.pca import PCA

# %%
data = sm.datasets.fertility.load_pandas().data
data.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Fertility rate, total (births per woman)
# 1      Andorra          AND  Fertility rate, total (births per woman)
# 2  Afghanistan          AFG  Fertility rate, total (births per woman)
# 3       Angola          AGO  Fertility rate, total (births per woman)
# 4      Albania          ALB  Fertility rate, total (births per woman)
#
#    Indicator Code   1960   1961   1962   1963   1964   1965  ...   2004  \
# 0  SP.DYN.TFRT.IN  4.820  4.655  4.471  4.271  4.059  3.842  ...  1.786
# 1  SP.DYN.TFRT.IN    NaN    NaN    NaN    NaN    NaN    NaN  ...    NaN
# 2  SP.DYN.TFRT.IN  7.671  7.671  7.671  7.671  7.671  7.671  ...  7.136
# 3  SP.DYN.TFRT.IN  7.316  7.354  7.385  7.410  7.425  7.430  ...  6.704
# 4  SP.DYN.TFRT.IN  6.186  6.076  5.956  5.833  5.711  5.594  ...  2.004
#
#     2005   2006   2007   2008   2009   2010   2011  2012  2013
# ...

# %%
columns = list(map(str, range(1960, 2012)))

data.set_index('Country Name', inplace=True)
dta = data[columns]
dta = dta.dropna()
dta.head()
# Out:
#                        1960   1961   1962   1963   1964   1965   1966   1967  \
# Country Name
# Aruba                 4.820  4.655  4.471  4.271  4.059  3.842  3.625  3.417
# Afghanistan           7.671  7.671  7.671  7.671  7.671  7.671  7.671  7.671
# Angola                7.316  7.354  7.385  7.410  7.425  7.430  7.422  7.403
# Albania               6.186  6.076  5.956  5.833  5.711  5.594  5.483  5.376
# United Arab Emirates  6.928  6.910  6.893  6.877  6.861  6.841  6.816  6.783
#
#                        1968   1969  ...   2002   2003   2004   2005   2006  \
# Country Name                        ...
# Aruba                 3.226  3.054  ...  1.825  1.805  1.786  1.769  1.754
# Afghanistan           7.671  7.671  ...  7.484  7.321  7.136  6.930  6.702
# Angola                7.375  7.339  ...  6.778  6.743  6.704  6.657  6.598
# Albania               5.268  5.160  ...  2.195  2.097  2.004  1.919  1.849
# ...

# %%
ax = dta.mean().plot(grid=False) #media da taxa de fertilidade 
ax.set_xlabel("Year", size=17)
ax.set_ylabel("Fertility rate", size=17);
ax.set_xlim(0, 51)
# Out:
# /Users/walter/opt/anaconda3/envs/CrashCourse/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# (0.0, 51.0)

# %%
# %%time
pca_model = PCA(dta.T, standardize=False, demean=True)
# Out:
# CPU times: user 233 ms, sys: 18 ms, total: 251 ms
# Wall time: 372 ms

# %%
fig = pca_model.plot_scree(log_scale=False)

# %%
import matplotlib.dates as mdates

# %%
fig, ax = plt.subplots(figsize=(14, 7))
lines = ax.plot(pca_model.factors.iloc[:,:3], lw=4, alpha=.6)
# ax.set_xticklabels(dta.columns.values[::10])
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.set_xlim(0, 51)
ax.set_xlabel("Year", size=17)
fig.subplots_adjust(.1, .1, .85, .9)
legend = fig.legend(lines, ['PC 1', 'PC 2', 'PC 3'], loc='center right')
legend.draw_frame(False)
plt.title("Tendencias!")
# Out:
# Text(0.5, 1.0, 'Tendencias!')

# %%
idx = pca_model.loadings.iloc[:,0].argsort()

# %%
idx
# Out:
# Country Name
# Aruba                   116
# Afghanistan              98
# Angola                   48
# Albania                  94
# United Arab Emirates    173
#                        ...
# Yemen, Rep.             156
# South Africa            124
# Congo, Dem. Rep.        170
# Zambia                  165
# Zimbabwe                189
# Name: comp_00, Length: 192, dtype: int64

# %%
def make_plot(labels):
    fig, ax = plt.subplots(figsize=(9,5))
    ax = dta.loc[labels].T.plot(legend=False, grid=False, ax=ax)
    dta.mean().plot(ax=ax, grid=False, label='Mean')
    ax.set_xlim(0, 51);
    fig.subplots_adjust(.1, .1, .75, .9)
    ax.set_xlabel("Year", size=17)
    ax.set_ylabel("Fertility", size=17);
    legend = ax.legend(*ax.get_legend_handles_labels(), loc='center left', bbox_to_anchor=(1, .5))
    legend.draw_frame(False)

# %%
labels = dta.index[idx[-5:]]
make_plot(labels)
# Out:
# /Users/walter/opt/anaconda3/envs/CrashCourse/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
idx = pca_model.loadings.iloc[:,1].argsort()
make_plot(dta.index[idx[-5:]])
# Out:
# /Users/walter/opt/anaconda3/envs/CrashCourse/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
make_plot(dta.index[idx[:5]])
# Out:
# /Users/walter/opt/anaconda3/envs/CrashCourse/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
fig, ax = plt.subplots()
pca_model.loadings.plot.scatter(x='comp_00',y='comp_01', ax=ax)
ax.set_xlabel("PC 1", size=17)
ax.set_ylabel("PC 2", size=17)
dta.index[pca_model.loadings.iloc[:, 1] > .2].values
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# array(['Oman', 'Yemen, Rep.'], dtype=object)
